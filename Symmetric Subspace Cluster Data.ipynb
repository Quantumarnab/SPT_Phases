# %% [markdown]
# #  Rounding off to nearest even and odd integers

# %%
function round_odd(N)
   val=Int64(round(N))
    if (val%2)==0     
     if (N-val)>=0
        val+=1
     else
        val-=1
    end
    end
   return val     
end

function round_even(N)
   val=Int64(round(N))
    if (val%2)==1    
     if (N-val)>0
        val+=1
     else
        val-=1 
     end
    end
   return val     
end
# Out:
# round_even (generic function with 1 method)

# %% [markdown]
# # Script for calculating Symmetry expectations
#
# ### The following function returns $\langle Z_{1}X_{2}X_{5}...X_{N-1}Z_{N}\rangle$ and $\langle X_{1}X_{3}X_{5}...X_{N}\rangle$ with respect to the MPS representation T.

# %%
using ITensors


function Sym1(T::MPS,N) 
   
   mps=copy(T);
   val=copy(T);
    
   s = siteind(mps,1)
   newpsi= 2*op(s,"Sz")*mps[1]
   noprime!(newpsi)
   mps[1]= newpsi
    
    for o = (2):2:(N-1)
           s = siteind(mps,o)
           newpsi= 2*op(s,"Sx")*mps[o]
           noprime!(newpsi)
           mps[o]= newpsi
    end
    
   s = siteind(mps,N)
   newpsi= 2*op(s,"Sz")*mps[N]
   noprime!(newpsi)
   mps[N]= newpsi
    
   expectation=inner(mps,val)
    
  return expectation
end

function Sym2(T::MPS,N)  
   
   mps=copy(T);
   val=copy(T);
    
    for o = (1):2:(N)
           s = siteind(mps,o)
           newpsi= 2*op(s,"Sx")*mps[o]
           noprime!(newpsi)
           mps[o]= newpsi
    end
    
    
   expectation=inner(mps,val)
    
  return expectation
end
# Out:
# Sym2 (generic function with 1 method)

# %%
using ITensors


function U1(T::MPS,N) 
   
   mps=copy(T);
   val=copy(T);
    
   s = siteind(mps,1)
   newpsi= 2*op(s,"Sz")*mps[1]
   noprime!(newpsi)
   mps[1]= newpsi
    
    for o = (2):2:(N-1)
           s = siteind(mps,o)
           newpsi= 2*op(s,"Sx")*mps[o]
           noprime!(newpsi)
           mps[o]= newpsi
    end
    
   s = siteind(mps,N)
   newpsi= 2*op(s,"Sz")*mps[N]
   noprime!(newpsi)
   mps[N]= newpsi
    
    
  return mps
end

function U2(T::MPS,N)  
   
   mps=copy(T);
   val=copy(T);
    
    for o = (1):2:(N)
           s = siteind(mps,o)
           newpsi= 2*op(s,"Sx")*mps[o]
           noprime!(newpsi)
           mps[o]= newpsi
    end
    
    
  return mps
end
# Out:
# U2 (generic function with 1 method)

# %%
using ITensors

function R1(T::MPS,start,finish)
    
    if start==finish
        return 1
    else
   
       mps=copy(T)

       s = siteind(mps,start)
       newpsi= 2*op(s,"Sz")*mps[start]
       noprime!(newpsi)
       mps[start]= newpsi

        for o = (start+1):2:(finish-1)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sx")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end

       s = siteind(mps,finish)
       newpsi= 2*op(s,"Sz")*mps[finish]
       noprime!(newpsi)
       mps[finish]= newpsi


        return mps 
    end
end


function R2(T::MPS,start,finish)
    
    if start==finish
        return 1
    else
   
       mps=copy(T)

       s = siteind(mps,start)
       newpsi= 2*op(s,"Sz")*mps[start]
       noprime!(newpsi)
       mps[start]= newpsi

        for o = (start+1):2:(finish)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sx")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end


        return mps 
    end
end
# Out:
# R2 (generic function with 1 method)

# %%
using ITensors
    acc=1E-13
    bond_dim=50
    Ndel=100
    Nlist=[401]
    SOP1= Array{Float64,1}(undef,Ndel+1)
    SOP2= Array{Float64,1}(undef,Ndel+1)
    error=Array{Float64,1}(undef,Ndel+1)
for N in Nlist # only odd input please
    sites = siteinds("S=1/2",N)
    psi0 = randomMPS(sites,bond_dim)
    @show Initial=round_odd(N/2) 
    printstyled("START OF A NEW CHAIN LENGTH \n"; color = :red)
    println("Chain length=$N")
    
    for nloop in 1:(Ndel+1)
    
      alpha= pi*(nloop-1)/(2*Ndel)
      s_p=((nloop-1)*100/Ndel);
      cs=cos(alpha)
      ss=sin(alpha)
      ampo = AutoMPO()
      for j=2:N-1
        ampo += -8*cs,"Sz",j-1,"Sx",j,"Sz",j+1;
      end
      ampo+= -4*cs,"Sz",N-1,"Sx",N;
      ampo+= -4*cs,"Sx",1,"Sz",2;
      for j=2:N-1
        ampo+= -2*ss,"Sx",j
      end 
      H = MPO(ampo,sites)
      println("$s_p % into the sweep")
      sweeps = Sweeps(15) # number of sweeps is 15
      maxdim!(sweeps,10,20,50,100,200,400,500,600,700,800,1000) # gradually increase states kept
      cutoff!(sweeps,acc) # desired truncation error
      energy,T = dmrg(H,psi0,sweeps,outputlevel=0; svd_alg="qr_iteration")#Run the dmrg algorithm
      error[nloop]= ((inner(H,T,H,T)-energy*energy)/N^2)
      phi_1=U1(T,N)
      phi_2=U2(T,N)
      phi_12=U1(phi_2,N)
      norm= 1+inner(phi_1,T)+inner(phi_2,T)+inner(phi_12,T)
      @show norm 
      R1_T= R1(T,Initial,N)
      R2_T= R2(T,Initial+1,N)
      SOP1[nloop]=(inner(R1_T,T)+inner(R1_T,phi_1)+inner(R1_T,phi_2)+inner(R1_T,phi_12))/norm;
      SOP2[nloop]=(inner(R2_T,T)+inner(R2_T,phi_1)+inner(R2_T,phi_2)+inner(R2_T,phi_12))/norm;
      @show SOP1[nloop]
      @show SOP2[nloop]
       
    end
   using DelimitedFiles
   writedlm("Sym_subspace SOP1 N=$N accuracy=$acc.csv",SOP1,',')
   writedlm("Sym_subspace SOP2 N=$N accuracy=$acc.csv",SOP2,',')
   writedlm("Sym_subspace Error N=$N accuracy=$acc.csv",error,',')
end
# Out:
# Initial = round_odd(N / 2) = 201
# START OF A NEW CHAIN LENGTH
# Chain length=401
# 0.0 % into the sweep
# norm = 3.999999999999985
# SOP1[nloop] = 0.9999999999999988
# SOP2[nloop] = 0.9999999999999998
# 1.0 % into the sweep
# norm = 4.0
# SOP1[nloop] = 0.9999691490811251
# SOP2[nloop] = 0.9999691490811254
# 2.0 % into the sweep
# norm = 4.000000000000019
# SOP1[nloop] = 0.9998764953516157
# SOP2[nloop] = 0.9998764953516159
# 3.0 % into the sweep
# norm = 4.0000000000000195
# SOP1[nloop] = 0.9997217350548797
# SOP2[nloop] = 0.9997217350548815
# 4.0 % into the sweep
# norm = 4.000000000000013
# SOP1[nloop] = 0.9995043591231418
# SOP2[nloop] = 0.9995043591231415
# 5.0 % into the sweep
# norm = 4.000000000000031
# SOP1[nloop] = 0.9992236489189634
# SOP2[nloop] = 0.9992236489189628
# 6.0 % into the sweep
# norm = 4.000000000000007
# SOP1[nloop] = 0.9988786701753741
# SOP2[nloop] = 0.998878670175373
# 7.0 % into the sweep
# norm = 3.9999999999818385
# SOP1[nloop] = 0.9984682650121545
# SOP2[nloop] = 0.9984682650155888
# 8.0 % into the sweep
# norm = 3.9999999999240003
# SOP1[nloop] = 0.997991041970215
# SOP2[nloop] = 0.9979910419519159
# 9.0 % into the sweep
# norm = 3.999999999931626
# SOP1[nloop] = 0.9974453636990984
# SOP2[nloop] = 0.9974453636984244
# 10.0 % into the sweep
# norm = 3.9999999999796563
# SOP1[nloop] = 0.9968293324114565
# SOP2[nloop] = 0.9968293324677685
# 11.0 % into the sweep
# norm = 3.9999999999910987
# SOP1[nloop] = 0.996140772623323
# SOP2[nloop] = 0.9961407724996225
# 12.0 % into the sweep
# norm = 3.9999999999999676
# SOP1[nloop] = 0.9953772100499839
# SOP2[nloop] = 0.9953772100499844
# 13.0 % into the sweep
# norm = 4.000000000000021
# SOP1[nloop] = 0.994535849114298
# SOP2[nloop] = 0.9945358491142995
# 14.0 % into the sweep
# norm = 4.000000000000011
# SOP1[nloop] = 0.993613543958916
# SOP2[nloop] = 0.9936135439589155
# 15.0 % into the sweep
# norm = 3.9999999999999707
# SOP1[nloop] = 0.9926067668487466
# SOP2[nloop] = 0.9926067668487453
# 16.0 % into the sweep
# norm = 4.000000000000024
# SOP1[nloop] = 0.9915115706367514
# SOP2[nloop] = 0.9915115706367503
# 17.0 % into the sweep
# norm = 3.9999999999999885
# SOP1[nloop] = 0.9903235453037855
# SOP2[nloop] = 0.9903235453037849
# 18.0 % into the sweep
# norm = 3.9999999999999694
# SOP1[nloop] = 0.9890377674071732
# SOP2[nloop] = 0.9890377674071726
# 19.0 % into the sweep
# norm = 3.9999999999822187
# SOP1[nloop] = 0.9876487411612249
# SOP2[nloop] = 0.9876487411612347
# 20.0 % into the sweep
# norm = 3.999999999966512
# SOP1[nloop] = 0.9861503295852118
# SOP2[nloop] = 0.9861503295857856
# 21.0 % into the sweep
# norm = 3.9999999999992286
# SOP1[nloop] = 0.9845356738200894
# SOP2[nloop] = 0.9845356738200951
# 22.0 % into the sweep
# norm = 3.9999999999402434
# SOP1[nloop] = 0.9827970981177765
# SOP2[nloop] = 0.9827970981092509
# 23.0 % into the sweep
# norm = 3.9999999998935714
# SOP1[nloop] = 0.9809259976741876
# SOP2[nloop] = 0.9809259976406518
# 24.0 % into the sweep
# norm = 3.9999999998497002
# SOP1[nloop] = 0.9789127051416944
# SOP2[nloop] = 0.9789127052252269
# 25.0 % into the sweep
# norm = 3.9999999998207905
# SOP1[nloop] = 0.9767463320091051
# SOP2[nloop] = 0.976746332056839
# 26.0 % into the sweep
# norm = 3.999999999759728
# SOP1[nloop] = 0.9744145765706476
# SOP2[nloop] = 0.9744145765781511
# 27.0 % into the sweep
# norm = 3.9999999996162456
# SOP1[nloop] = 0.9719034940694206
# SOP2[nloop] = 0.9719034940725729
# 28.0 % into the sweep
# norm = 3.99999999951059
# SOP1[nloop] = 0.9691972143831109
# SOP2[nloop] = 0.9691972143915577
# 29.0 % into the sweep
# norm = 3.999999998741356
# SOP1[nloop] = 0.9662775952291938
# SOP2[nloop] = 0.9662775966748478
# 30.0 % into the sweep
# norm = 3.9999999988385735
# SOP1[nloop] = 0.9631238011350653
# SOP2[nloop] = 0.9631238024812147
# 31.0 % into the sweep
# norm = 3.999999999959975
# SOP1[nloop] = 0.9597117585614122
# SOP2[nloop] = 0.9597117585617099
# 32.0 % into the sweep
# norm = 3.9999999999983307
# SOP1[nloop] = 0.9560134952434483
# SOP2[nloop] = 0.9560134952434283
# 33.0 % into the sweep
# norm = 3.999999999999135
# SOP1[nloop] = 0.9519962647124802
# SOP2[nloop] = 0.9519962647123457
# 34.0 % into the sweep
# norm = 3.9999999999990914
# SOP1[nloop] = 0.9476214384127866
# SOP2[nloop] = 0.9476214384127878
# 35.0 % into the sweep
# norm = 3.9999999999941744
# SOP1[nloop] = 0.9428430392035272
# SOP2[nloop] = 0.9428430392027771
# 36.0 % into the sweep
# norm = 3.999999999928591
# SOP1[nloop] = 0.9376057861794651
# SOP2[nloop] = 0.937605786238484
# 37.0 % into the sweep
# norm = 3.999999999755048
# SOP1[nloop] = 0.9318424378609362
# SOP2[nloop] = 0.9318424377750198
# 38.0 % into the sweep
# norm = 3.999999999747393
# SOP1[nloop] = 0.9254701026164859
# SOP2[nloop] = 0.9254701033934871
# 39.0 % into the sweep
# norm = 3.999999999919229
# SOP1[nloop] = 0.9183849983042383
# SOP2[nloop] = 0.9183849983004846
# 40.0 % into the sweep
# norm = 3.9999999999860023
# SOP1[nloop] = 0.9104547886084645
# SOP2[nloop] = 0.9104547886116136
# 41.0 % into the sweep
# norm = 3.999999999995368
# SOP1[nloop] = 0.9015070012822811
# SOP2[nloop] = 0.9015070012844719
# 42.0 % into the sweep
# norm = 3.9999999999669402
# SOP1[nloop] = 0.8913108457327454
# SOP2[nloop] = 0.8913108457190754
# 43.0 % into the sweep
# norm = 3.9999999999098357
# SOP1[nloop] = 0.8795472508462755
# SOP2[nloop] = 0.8795472508545108
# 44.0 % into the sweep
# norm = 3.999999999993506
# SOP1[nloop] = 0.8657564953286899
# SOP2[nloop] = 0.8657564953276037
# 45.0 % into the sweep
# norm = 3.9999999999844493
# SOP1[nloop] = 0.8492394819384343
# SOP2[nloop] = 0.8492394819393747
# 46.0 % into the sweep
# norm = 3.9999999999647464
# SOP1[nloop] = 0.8288518060949974
# SOP2[nloop] = 0.8288518059726954
# 47.0 % into the sweep
# norm = 3.9999999999906537
# SOP1[nloop] = 0.8025086257058154
# SOP2[nloop] = 0.8025086256743399
# 48.0 % into the sweep
# norm = 3.9999999999799374
# SOP1[nloop] = 0.7657016074129479
# SOP2[nloop] = 0.765701609110075
# 49.0 % into the sweep
# norm = 3.999999999979877
# SOP1[nloop] = 0.7048431711078191
# SOP2[nloop] = 0.7048427023229088
# 50.0 % into the sweep
# norm = 3.2303233490039673
# SOP1[nloop] = 0.5281114743834535
# SOP2[nloop] = 0.5337499028656124
# 51.0 % into the sweep
# norm = 0.27442259313114614
# SOP1[nloop] = 0.06035392091435655
# SOP2[nloop] = 0.060049751738438226
# 52.0 % into the sweep
# norm = 0.4015691635122274
# SOP1[nloop] = 0.0028477415479756067
# SOP2[nloop] = 0.002760574392879883
# 53.0 % into the sweep
# norm = 1.9887467061619184
# SOP1[nloop] = 0.00012236908069074631
# SOP2[nloop] = 0.0001178380042190663
# 54.0 % into the sweep
# norm = 1.9983650943044817
# SOP1[nloop] = 4.8317227996044555e-6
# SOP2[nloop] = 4.793191730802238e-6
# 55.0 % into the sweep
# norm = 1.988856909261988
# SOP1[nloop] = 1.8791177873137723e-7
# SOP2[nloop] = 1.8386522976054156e-7
# 56.0 % into the sweep
# norm = 1.9875499126008176
# SOP1[nloop] = 7.258512519218192e-9
# SOP2[nloop] = 7.430941895863966e-9
# 57.0 % into the sweep
# norm = 1.9870378828530413
# SOP1[nloop] = 2.4277508382896153e-10
# SOP2[nloop] = 3.258599534705889e-10
# 58.0 % into the sweep
# norm = 1.9960666956745885
# SOP1[nloop] = 1.028198969928563e-11
# SOP2[nloop] = 9.429653204317246e-12
# 59.0 % into the sweep
# norm = 1.7933483320100234
# SOP1[nloop] = -9.087472563797396e-13
# SOP2[nloop] = 5.910231140377388e-12
# 60.0 % into the sweep
# norm = 1.69738120399728
# SOP1[nloop] = -3.569378621439276e-13
# SOP2[nloop] = -4.728760861537952e-13
# 61.0 % into the sweep
# norm = 1.540875207123123
# SOP1[nloop] = -1.6914531284045827e-13
# SOP2[nloop] = -4.4809179164633227e-13
# 62.0 % into the sweep
# norm = 1.9921674913352014
# SOP1[nloop] = -2.5338489362300963e-13
# SOP2[nloop] = -2.909072386372089e-14
# 63.0 % into the sweep
# norm = 1.9785950604355311
# SOP1[nloop] = -2.916608729963465e-13
# SOP2[nloop] = -6.902161979793171e-13
# 64.0 % into the sweep
# norm = 1.4725242613947165
# SOP1[nloop] = 8.015414796034848e-13
# SOP2[nloop] = 1.0483483422015052e-13
# 65.0 % into the sweep
# norm = 1.1692430235715168
# SOP1[nloop] = 9.512808096877904e-14
# SOP2[nloop] = 9.436323058319789e-14
# 66.0 % into the sweep
# norm = 0.9692432254944512
# SOP1[nloop] = 1.5963275140143166e-13
# SOP2[nloop] = 2.102583700421491e-13
# 67.0 % into the sweep
# norm = 0.946454658013688
# SOP1[nloop] = 2.1437754581971498e-13
# SOP2[nloop] = 2.014768560311913e-13
# 68.0 % into the sweep
# norm = 1.2833150576874743
# SOP1[nloop] = 3.903823920186842e-13
# SOP2[nloop] = 1.406178415272727e-13
# 69.0 % into the sweep
# norm = 1.6305094166537397
# SOP1[nloop] = -6.463381681362296e-14
# SOP2[nloop] = -4.7679652238155665e-15
# 70.0 % into the sweep
# norm = 1.5496718995832697
# SOP1[nloop] = 3.5445107501623053e-13
# SOP2[nloop] = 1.1221327395450449e-13
# 71.0 % into the sweep
# norm = 1.5056138981967122
# SOP1[nloop] = 1.1083672548872882e-13
# SOP2[nloop] = 4.663718153312249e-14
# 72.0 % into the sweep
# norm = 1.3086723204549655
# SOP1[nloop] = 3.9899047615600305e-14
# SOP2[nloop] = -2.7706101073590023e-14
# 73.0 % into the sweep
# norm = 1.121399639744703
# SOP1[nloop] = 4.824380468374128e-13
# SOP2[nloop] = 2.4988208582132074e-13
# 74.0 % into the sweep
# norm = 1.1511053589072808
# SOP1[nloop] = 1.1049323859323785e-13
# SOP2[nloop] = -7.364606126327875e-14
# 75.0 % into the sweep
# norm = 1.8459599685770232
# SOP1[nloop] = 2.6695021886482025e-15
# SOP2[nloop] = 1.215235702319379e-13
# 76.0 % into the sweep
# norm = 1.9798717074727135
# SOP1[nloop] = -4.114612315851892e-14
# SOP2[nloop] = -3.21938402695407e-13
# 77.0 % into the sweep
# norm = 1.922442727764245
# SOP1[nloop] = 1.0987817979644284e-15
# SOP2[nloop] = -5.4320350440114116e-14
# 78.0 % into the sweep
# norm = 1.6945593853322931
# SOP1[nloop] = 2.58098643064956e-14
# SOP2[nloop] = 1.3555663995047209e-13
# 79.0 % into the sweep
# norm = 1.5429772942142255
# SOP1[nloop] = 2.8118092529100786e-14
# SOP2[nloop] = 6.117290589476667e-14
# 80.0 % into the sweep
# norm = 1.9436757513237466
# SOP1[nloop] = -3.657363942366226e-15
# SOP2[nloop] = -6.227421661616707e-14
# 81.0 % into the sweep
# norm = 1.9977452244592935
# SOP1[nloop] = -3.052802685321059e-14
# SOP2[nloop] = 5.837439947661842e-15
# 82.0 % into the sweep
# norm = 1.0690522306501542
# SOP1[nloop] = 6.13236968476269e-14
# SOP2[nloop] = 1.3040672327487266e-14
# 83.0 % into the sweep
# norm = 1.7560144954982921
# SOP1[nloop] = 7.364442424659867e-15
# SOP2[nloop] = -1.1195872233004301e-13
# 84.0 % into the sweep
# norm = 1.9277508490212356
# SOP1[nloop] = 4.51226416809045e-15
# SOP2[nloop] = -8.7013635717848e-14
# 85.0 % into the sweep
# norm = 1.8245398322980182
# SOP1[nloop] = 5.044321332757936e-15
# SOP2[nloop] = 1.2252743813527404e-14
# 86.0 % into the sweep
# norm = 1.9770282782390542
# SOP1[nloop] = -3.503396656409502e-15
# SOP2[nloop] = 9.97045422758726e-15
# 87.0 % into the sweep
# norm = 1.7578467182628614
# SOP1[nloop] = -4.874344273966818e-15
# SOP2[nloop] = -5.084317332147659e-14
# 88.0 % into the sweep
# norm = 1.8177845226733789
# SOP1[nloop] = 1.8208899318539593e-14
# SOP2[nloop] = -1.4500326096489925e-13
# 89.0 % into the sweep
# norm = 1.6922588348383094
# SOP1[nloop] = -4.204199603202194e-15
# SOP2[nloop] = -1.6122989332051507e-14
# 90.0 % into the sweep
# norm = 1.6475694573457598
# SOP1[nloop] = 1.4749585295897134e-14
# SOP2[nloop] = 4.515442589085231e-14
# 91.0 % into the sweep
# norm = 1.6728003190437482
# SOP1[nloop] = -2.0918410587050772e-14
# SOP2[nloop] = 1.524504084909199e-14
# 92.0 % into the sweep
# norm = 1.6851101848002132
# SOP1[nloop] = 3.7882890645739186e-14
# SOP2[nloop] = -1.6181345144671803e-13
# 93.0 % into the sweep
# norm = 1.6209507813919837
# SOP1[nloop] = -1.843127084893775e-14
# SOP2[nloop] = -2.6891260454757978e-14
# 94.0 % into the sweep
# norm = 1.3405145018796687
# SOP1[nloop] = -1.2011862167024854e-14
# SOP2[nloop] = -7.403855570222389e-14
# 95.0 % into the sweep
# norm = 1.699384515305339
# SOP1[nloop] = -1.479865992673827e-14
# SOP2[nloop] = 7.12699712485777e-14
# 96.0 % into the sweep
# norm = 1.002684714710583
# SOP1[nloop] = -3.457173062146047e-14
# SOP2[nloop] = 9.924646598526435e-14
# 97.0 % into the sweep
# norm = 1.1483643881993542
# SOP1[nloop] = -2.0610918174450422e-15
# SOP2[nloop] = 2.5723709301288447e-14
# 98.0 % into the sweep
# norm = 1.459827138806555
# SOP1[nloop] = -3.407200703314508e-14
# SOP2[nloop] = 4.4478171804603696e-14
# 99.0 % into the sweep
# norm = 0.9607254714298403
# SOP1[nloop] = 2.682919142202314e-15
# SOP2[nloop] = 2.6023389825047272e-14
# 100.0 % into the sweep
# norm = 1.9384059458673994
# SOP1[nloop] = 6.908247583501056e-15
# SOP2[nloop] = -1.9013544672380737e-15

# %%
using LaTeXStrings
N =7 # only odd input please
acc=1E-13
Ndel=100
using DelimitedFiles
SOP1= readdlm("Sym_subspace SOP1 N=$N accuracy=$acc.csv",',')
SOP2= readdlm("Sym_subspace SOP2 N=$N accuracy=$acc.csv",',')
swe= LinRange(0,1,Ndel+1)

using Plots
pyplot()
plt=plot!(swe,SOP1, #ylims = (0,1),
    title ="Symmetry Check",label=:false,linecolor=:red,
    legend=:topright,fmt = :png,dpi=300,reuse=false) 
xlabel!(L"\frac{2\alpha}{\pi}")
ylabel!(L"\langle g_{01} \rangle")
scatter!(swe,Symmetry[:,1],label="N=$N",markersize=4,markercolor=:red,reuse=false,markershape=:circle)
#display(plt2)
#png("2ν₀₁ diff chain lengths accuracy=$acc")

# %%
using ITensors

  N = 10
  sites = siteinds("Qubit",N;conserve_qns=true)
  state_a = [ (isequal(n,1)|| isequal(n,N)) ? "0" : "X+" for n=1:N ] 
  psi_a = productMPS(sites,state)
# Out:
# ArgumentError: Overload of "state" or "state!" functions not found for state name "X+" and Index tags "Qubit,Site,n=1"
#
# Stacktrace:
#   [1] state(s::Index{Vector{Pair{QN, Int64}}}, name::String; kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ ITensors ~/.julia/packages/ITensors/ogw8Q/src/physics/sitetype.jl:488
#   [2] state
#     @ ~/.julia/packages/ITensors/ogw8Q/src/physics/sitetype.jl:462 [inlined]
#   [3] #843
#     @ ./none:0 [inlined]
#   [4] iterate
#     @ ./generator.jl:47 [inlined]
#   [5] collect(itr::Base.Generator{UnitRange{Int64}, ITensors.var"#843#845"{Vector{Index{Vector{Pair{QN, Int64}}}}, Vector{String}}})
#     @ Base ./array.jl:681
#   [6] MPS(#unused#::Type{Float64}, sites::Vector{Index{Vector{Pair{QN, Int64}}}}, states_::Vector{String})
#     @ ITensors ~/.julia/packages/ITensors/ogw8Q/src/mps/mps.jl:320
#   [7] MPS(sites::Vector{Index{Vector{Pair{QN, Int64}}}}, states::Vector{String})
#     @ ITensors ~/.julia/packages/ITensors/ogw8Q/src/mps/mps.jl:377
#   [8] top-level scope
#     @ In[34]:6
#   [9] eval
#     @ ./boot.jl:360 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116
