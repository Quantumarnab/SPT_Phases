# %%
function round_odd(N)
   val=Int64(round(N))
    if (val%2)==0     
     if (N-val)>=0
        val+=1
     else
        val-=1
    end
    end
   return val     
end

function round_even(N)
   val=Int64(round(N))
    if (val%2)==1    
     if (N-val)>0
        val+=1
     else
        val-=1 
     end
    end
   return val     
end

# %%
round_odd(600/2)

# %% [markdown]
# # Kitaev-Gamma Chain (Arxiv:1910.14304)
#
# ## $$\displaystyle \widetilde{H}(\Phi)= \sum_{\; \; \langle i,j \rangle \\ \in \, \gamma  \text{ bond }} -\sin\Phi \;S_{i}^{\gamma} S_{j}^{\gamma}- \cos\Phi\;(S_{i}^{\alpha} S_{j}^{\alpha}+S_{i}^{\beta} S_{j}^{\beta}),$$
# ###  where $\alpha,\beta \neq \gamma$.

# %% [markdown]
# ## Symmetry Element $\langle ...XXXX...\rangle$ and $\langle \ldots ZZZZ \ldots \rangle$

# %%
using ITensors

function KitaevSymmetryX(T::MPS,start,finish)
    
        mps=copy(T)
        new=copy(T)
        
        for o = (start):1:(finish)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sx")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end
            expectation=inner(mps,new)
        return expectation 
end

using ITensors

function KitaevSymmetryZ(T::MPS,start,finish)
    
        mps=copy(T)
        new=copy(T)
        
        for o = (start):1:(finish)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sz")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end
        expectation=inner(mps,new)
        return expectation 
end

# %%
using ITensors

    N=600
    acc=1E-10
    bond_dim=50
    sites = siteinds("S=1/2",N)
    psi0 = randomMPS(sites,bond_dim)
    D_length=101
    SOPX_odd_bulk=Array{Float64,1}(undef,D_length)
    SOPZ_odd_bulk=Array{Float64,1}(undef,D_length)
    SOPX_even_bulk=Array{Float64,1}(undef,D_length)
    SOPZ_even_bulk=Array{Float64,1}(undef,D_length)
    SOPX_odd_end=Array{Float64,1}(undef,D_length)
    SOPZ_odd_end=Array{Float64,1}(undef,D_length)
    SOPX_even_end=Array{Float64,1}(undef,D_length)
    SOPZ_even_end=Array{Float64,1}(undef,D_length)
    D_store=Array{Float64,1}(undef,D_length)
    sweep=0.15
    phi=-sweep*pi
    cs=cos(phi)
    ss=sin(phi)
    count=0
    
    for D in LinRange(-1, 1, D_length)
        count+=1
        g1=1.0; g2=g1*10.0^D;
        g=Array{Float64,1}(undef,N-1)
        for i=1:length(g)

            if i%2==1
                g[i]=g1;
            else
                g[i]=g2;
            end
        end
        ampo = AutoMPO()
        for j=1:3:N
            ampo += -4*ss*g[j],"Sx",j,"Sx",j+1;
            ampo += -4*cs*g[j],"Sz",j,"Sz",j+1;
            ampo += -4*cs*g[j],"Sy",j,"Sy",j+1;
        end
        for j=2:3:N
            ampo += -4*ss*g[j],"Sz",j,"Sz",j+1;
            ampo += -4*cs*g[j],"Sy",j,"Sy",j+1;
            ampo += -4*cs*g[j],"Sx",j,"Sx",j+1;
        end
        for j=3:3:N-1
            ampo += -4*ss*g[j],"Sy",j,"Sy",j+1;
            ampo += -4*cs*g[j],"Sx",j,"Sx",j+1;
            ampo += -4*cs*g[j],"Sz",j,"Sz",j+1;
        end
        H = MPO(ampo,sites)
        sweeps = Sweeps(15) # number of sweeps is 15
        maxdim!(sweeps,10,20,50,100,200,400,500,600,700) # gradually increase states kept
        cutoff!(sweeps,acc) # desired truncation error
        E0,Kita = dmrg(H,psi0,sweeps,outputlevel=0)#Run the dmrg algorithm
        @show SOPX_odd_end[count]=real(KitaevSymmetryX(Kita,round_even(N/2),N-1))
        @show SOPZ_odd_end[count]=real(KitaevSymmetryZ(Kita,round_even(N/2),N-1))
        @show SOPX_even_end[count]=real(KitaevSymmetryX(Kita,round_odd(N/2),N))
        @show SOPZ_even_end[count]=real(KitaevSymmetryZ(Kita,round_odd(N/2),N))
        SOPX_odd_bulk[count]=real(KitaevSymmetryX(Kita,round_even(N/4),round_odd(3N/4)))
        SOPZ_odd_bulk[count]=real(KitaevSymmetryZ(Kita,round_even(N/4),round_odd(3N/4)))
        SOPX_even_bulk[count]=real(KitaevSymmetryX(Kita,round_odd(N/4),round_even(3N/4)))
        SOPZ_even_bulk[count]=real(KitaevSymmetryZ(Kita,round_odd(N/4),round_even(3N/4)))
        @show D_store[count]= D
    
    end
   
    using DelimitedFiles
        writedlm("x_end_SOPX_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_odd_bulk,',')
        writedlm("x_end_SOPZ_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_odd_bulk,',')
        writedlm("x_end_SOPX_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_even_bulk,',')
        writedlm("x_end_SOPZ_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_even_bulk,',')
        writedlm("x_end_SOPX_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_odd_end,',')
        writedlm("x_end_SOPZ_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_odd_end,',')
        writedlm("x_end_SOPX_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_even_end,',')
        writedlm("x_end_SOPZ_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_even_end,',')
# Out:
# D_store[count] = D = 0.3999999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9332177180927401
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.922851073885329
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -2.2131595462469983e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3810359995689863e-14
# D_store[count] = D = 0.41999999999999993
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9399962162027178
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9303895868169308
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.137444965045649e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.308608189179087e-10
# D_store[count] = D = 0.43999999999999995
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9460507834247875
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9371578725850173
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 7.885867345001667e-9
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -2.291314093976229e-9
# D_store[count] = D = 0.45999999999999996
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9514636176743356
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9432394360023546
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.303867703099189e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -6.176552617028624e-15
# D_store[count] = D = 0.48
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9563068882107025
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9487080123108513
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.7170779174240203e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3986873727245506e-15
# D_store[count] = D = 0.5
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9606440751888936
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.953628821646221
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.1205844936228505e-13
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.4241804942115136e-14
# D_store[count] = D = 0.52
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.964531108831675
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9580596603074106
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -5.608084191599963e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.8824109839599e-15
# D_store[count] = D = 0.54
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.968017309562248
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.962051793047912
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.0506430276495764e-13
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.5519355197986122e-14
# D_store[count] = D = 0.56
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9711462615443206
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9656507830316375
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.9424109598957185e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3618364312166404e-14
# D_store[count] = D = 0.5800000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.973956497031499
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9688971528766489
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.23513120622348e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -4.6983809780246817e-14
# D_store[count] = D = 0.6000000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9764821466399379
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9718270022756268
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.1744399709335275e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.158256061664176e-15
# D_store[count] = D = 0.6200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.978753463103011
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.974472517982235
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.256687855386847e-13
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 7.420961507650572e-15
# D_store[count] = D = 0.6399999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9807972957385829
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9768624316299096
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.9561115737182197e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 3.784934734462902e-14
# D_store[count] = D = 0.6599999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9826374941652926
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9790224124931021
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 4.474709960939578e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -4.347462235023225e-14
# D_store[count] = D = 0.6799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9842952725686761
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9809754245450588
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -8.50276687175311e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 4.22879246982101e-14
# D_store[count] = D = 0.7
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9857895094065404
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9827420140487868
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.0400003955488641e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -4.3134094710122114e-14
# D_store[count] = D = 0.72
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9871370294921694
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.984340599140683
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.4961528219815996e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.719158396756821e-14
# D_store[count] = D = 0.74
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9883528324296579
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.985787688273691
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.532065325148555e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.590661942663311e-15
# D_store[count] = D = 0.76
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9894503111013835
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9870980992599566
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.1436074081466137e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 8.959948120130893e-14
# D_store[count] = D = 0.78
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9904414272583837
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9882851375358651
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.4061248099371925e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.830301053853593e-14
# D_store[count] = D = 0.8
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9913368754783036
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9893607597005127
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.204260475152196e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.867140947978692e-14
# D_store[count] = D = 0.8200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9921462246833916
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9903357176139714
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.076856447630581e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.1610035596478765e-14
# D_store[count] = D = 0.8400000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.992878037565054
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9912196811380559
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 4.1646421455828295e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.1934275842612369e-10
# D_store[count] = D = 0.8600000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9935400044870453
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9920213732674702
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.0308858691936884e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.252835937592365e-10
# D_store[count] = D = 0.8799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9941390082772557
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9927486400623833
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.046161861950985e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3298739588099198e-13
# D_store[count] = D = 0.8999999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9946812152543385
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9934085435053717
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.0986075739452665e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 3.119574504123613e-15
# D_store[count] = D = 0.9199999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9951721795973465
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9940074706150703
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.211660989451181e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 7.602033630654938e-14
# D_store[count] = D = 0.94
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9956168856741688
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9945511779111219
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 4.665590299106548e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.975692858008457e-14
# D_store[count] = D = 0.96
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9960198143894807
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9950448624441516
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.8330985320680732e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.5083157335058115e-16
# D_store[count] = D = 0.98
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9963849968141153
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9954932179294125
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.458525631265341e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.0234817781693195e-14
# D_store[count] = D = 1.0

# %%
N=600
sweep=0.15
D_length=101
acc=1E-10
using DelimitedFiles
SOPX_odd_end=readdlm("x_end_SOPX_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_odd_end=readdlm("x_end_SOPZ_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPX_even_end=readdlm("x_end_SOPX_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_even_end=readdlm("x_end_SOPZ_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
D_store=LinRange(-1,1,D_length)
SOPX_odd_bulk=readdlm("x_end_SOPX_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_odd_bulk=readdlm("x_end_SOPZ_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPX_even_bulk=readdlm("x_end_SOPX_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_even_bulk=readdlm("x_end_SOPZ_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')

# %%
using Plots
using LaTeXStrings
pyplot()
    p1= plot(D_store,SOPX_even_end,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPX_even_end,label=L"O_{e}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:red)
    plot!(D_store,SOPX_odd_end,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPX_odd_end,label=L"O_{o}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:green)
    plot!(D_store,SOPZ_even_end,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPZ_even_end,label=L"O_{e}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:red)
    plot!(D_store,SOPZ_odd_end,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPZ_odd_end,label=L"O_{o}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:green)
    xlabel!(L"\log_{10}(g)")
    ylabel!(L"O_{e/o}^{x/z}")
    #png("x_end_SOPX_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
png("x_end_SOPX_end_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
using Plots
using LaTeXStrings
pyplot()
    p1= plot(D_store,SOPX_even_bulk,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPX_even_bulk,label=L"O_{e}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:red)
    plot!(D_store,SOPX_odd_bulk,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPX_odd_bulk,label=L"O_{o}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:green)
    plot!(D_store,SOPZ_even_bulk,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPZ_even_bulk,label=L"O_{e}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:red)
    plot!(D_store,abs.(SOPZ_odd_bulk),label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,abs.(SOPZ_odd_bulk),label=L"O_{o}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:green)
    xlabel!(L"\log_{10}(g)")
    ylabel!(L"O_{e/o}^{x/z}")
    #png("y_end_SOPX_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
png("x_end_SOPX_bulk_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")
