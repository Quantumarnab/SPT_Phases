# %%
function round_odd(N)
   val=Int64(round(N))
    if (val%2)==0     
     if (N-val)>=0
        val+=1
     else
        val-=1
    end
    end
   return val     
end

function round_even(N)
   val=Int64(round(N))
    if (val%2)==1    
     if (N-val)>0
        val+=1
     else
        val-=1 
     end
    end
   return val     
end
# Out:
# round_even (generic function with 1 method)

# %%
round_odd(600/2)
# Out:
# 301

# %% [markdown]
# # Kitaev-Gamma Chain (Arxiv:1910.14304)
#
# ## $$\displaystyle \widetilde{H}(\Phi)= \sum_{\; \; \langle i,j \rangle \\ \in \, \gamma  \text{ bond }} -\sin\Phi \;S_{i}^{\gamma} S_{j}^{\gamma}- \cos\Phi\;(S_{i}^{\alpha} S_{j}^{\alpha}+S_{i}^{\beta} S_{j}^{\beta}),$$
# ###  where $\alpha,\beta \neq \gamma$.

# %% [markdown]
# ## Symmetry Element $\langle ...XXXX...\rangle$ and $\langle \ldots ZZZZ \ldots \rangle$

# %%
using ITensors

function KitaevSymmetryX(T::MPS,start,finish)
    
        mps=copy(T)
        new=copy(T)
        
        for o = (start):1:(finish)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sx")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end
            expectation=inner(mps,new)
        return expectation 
end

using ITensors

function KitaevSymmetryZ(T::MPS,start,finish)
    
        mps=copy(T)
        new=copy(T)
        
        for o = (start):1:(finish)
               s = siteind(mps,o)
               newpsi= 2*op(s,"Sz")*mps[o]
               noprime!(newpsi)
               mps[o]= newpsi
        end
        expectation=inner(mps,new)
        return expectation 
end
# Out:
# KitaevSymmetryZ (generic function with 1 method)

# %%
using ITensors

    N=600
    acc=1E-10
    bond_dim=50
    sites = siteinds("S=1/2",N)
    psi0 = randomMPS(sites,bond_dim)
    D_length=101
    SOPX_odd_bulk=Array{Float64,1}(undef,D_length)
    SOPZ_odd_bulk=Array{Float64,1}(undef,D_length)
    SOPX_even_bulk=Array{Float64,1}(undef,D_length)
    SOPZ_even_bulk=Array{Float64,1}(undef,D_length)
    SOPX_odd_end=Array{Float64,1}(undef,D_length)
    SOPZ_odd_end=Array{Float64,1}(undef,D_length)
    SOPX_even_end=Array{Float64,1}(undef,D_length)
    SOPZ_even_end=Array{Float64,1}(undef,D_length)
    D_store=Array{Float64,1}(undef,D_length)
    sweep=0.15
    phi=-sweep*pi
    cs=cos(phi)
    ss=sin(phi)
    count=0
    
    for D in LinRange(-1, 1, D_length)
        count+=1
        g1=1.0; g2=g1*10.0^D;
        g=Array{Float64,1}(undef,N-1)
        for i=1:length(g)

            if i%2==1
                g[i]=g2;
            else
                g[i]=g1;
            end
        end
        ampo = AutoMPO()
        for j=1:3:N
            ampo += -4*ss*g[j],"Sy",j,"Sy",j+1;
            ampo += -4*cs*g[j],"Sz",j,"Sz",j+1;
            ampo += -4*cs*g[j],"Sx",j,"Sx",j+1;
        end
        for j=2:3:N
            ampo += -4*ss*g[j],"Sx",j,"Sx",j+1;
            ampo += -4*cs*g[j],"Sy",j,"Sy",j+1;
            ampo += -4*cs*g[j],"Sz",j,"Sz",j+1;
        end
        for j=3:3:N-1
            ampo += -4*ss*g[j],"Sz",j,"Sz",j+1;
            ampo += -4*cs*g[j],"Sx",j,"Sx",j+1;
            ampo += -4*cs*g[j],"Sy",j,"Sy",j+1;
        end
        H = MPO(ampo,sites)
        sweeps = Sweeps(15) # number of sweeps is 15
        maxdim!(sweeps,10,20,50,100,200,400,500,600,700) # gradually increase states kept
        cutoff!(sweeps,acc) # desired truncation error
        E0,Kita = dmrg(H,psi0,sweeps,outputlevel=0)#Run the dmrg algorithm
        @show SOPX_odd_end[count]=real(KitaevSymmetryX(Kita,round_even(N/2),N-1))
        @show SOPZ_odd_end[count]=real(KitaevSymmetryZ(Kita,round_even(N/2),N-1))
        @show SOPX_even_end[count]=real(KitaevSymmetryX(Kita,round_odd(N/2),N))
        @show SOPZ_even_end[count]=real(KitaevSymmetryZ(Kita,round_odd(N/2),N))
        SOPX_odd_bulk[count]=real(KitaevSymmetryX(Kita,round_even(N/4),round_odd(3N/4)))
        SOPZ_odd_bulk[count]=real(KitaevSymmetryZ(Kita,round_even(N/4),round_odd(3N/4)))
        SOPX_even_bulk[count]=real(KitaevSymmetryX(Kita,round_odd(N/4),round_even(3N/4)))
        SOPZ_even_bulk[count]=real(KitaevSymmetryZ(Kita,round_odd(N/4),round_even(3N/4)))
        @show D_store[count]= D
    
    end
   
    using DelimitedFiles
        writedlm("y_end_SOPX_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_odd_bulk,',')
        writedlm("y_end_SOPZ_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_odd_bulk,',')
        writedlm("y_end_SOPX_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_even_bulk,',')
        writedlm("y_end_SOPZ_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_even_bulk,',')
        writedlm("y_end_SOPX_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_odd_end,',')
        writedlm("y_end_SOPZ_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_odd_end,',')
        writedlm("y_end_SOPX_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPX_even_end,',')
        writedlm("y_end_SOPZ_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",SOPZ_even_end,',')
# Out:
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.995493218017144
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9973698466832595
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -7.099422723523831e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.0529254310655475e-13
# D_store[count] = D = -1.0
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.995044862574013
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9971014734157411
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 5.485657853340437e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.5769884715830184e-14
# D_store[count] = D = -0.98
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9945511780944072
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9968049231558309
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -5.3747615859249894e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.233359607224861e-14
# D_store[count] = D = -0.96
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9940074708569427
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9964771141422221
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 2.1436616882895654e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.090198266050623e-14
# D_store[count] = D = -0.94
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9934085438124389
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.996114608102717
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 2.2594267146064384e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.0769297986768497e-13
# D_store[count] = D = -0.9199999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9927486404332195
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9957135662476998
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 4.609567469270099e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 5.0874256817110575e-14
# D_store[count] = D = -0.8999999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9920213732216424
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9952696924787152
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.46183278080355e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -5.220323128954418e-10
# D_store[count] = D = -0.8799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9912196811666394
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9947781992352326
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 2.741993898677379e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.364303274221049e-11
# D_store[count] = D = -0.8599999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9903357176067981
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9942337189166167
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.83812235359365e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 8.665318305198658e-14
# D_store[count] = D = -0.8400000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9893607597815626
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9936302208289334
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.348142232714395e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -9.042962081894568e-15
# D_store[count] = D = -0.8200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.988285137495571
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9929609607624144
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 4.020092641212145e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.199474143589106e-13
# D_store[count] = D = -0.8
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9870980991545121
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9922183611908991
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.8411195039053504e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.299542750704618e-14
# D_store[count] = D = -0.78
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9857876883259165
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9913939055551064
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.630566756263858e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3769553459900346e-13
# D_store[count] = D = -0.76
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.984340599025972
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9904780106404799
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.813588308466945e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -8.613014596661001e-14
# D_store[count] = D = -0.74
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9827420133598296
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9894598801522856
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.5429858188799174e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 3.655255870202386e-14
# D_store[count] = D = -0.72
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9809754226875793
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9883273413387077
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.168101993481451e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.425646413361738e-15
# D_store[count] = D = -0.7
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9790224132070756
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9870666495968217
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.58538168368106e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.7163731201653257e-14
# D_store[count] = D = -0.6799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9768624326820892
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.985662260679836
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 5.942548025818503e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.7801559989533695e-14
# D_store[count] = D = -0.6599999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9744725208611594
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9840965754620759
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 5.546217701397304e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 8.497954789049135e-14
# D_store[count] = D = -0.6400000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9718270016611075
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9823496363530502
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.2108769783651493e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.695186632731075e-14
# D_store[count] = D = -0.6200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9688971519574968
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9803987936278331
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.952027871085012e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.0477681913448472e-13
# D_store[count] = D = -0.6000000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9656507817013703
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9782182779656491
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -2.579685281032193e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 9.58082325413911e-14
# D_store[count] = D = -0.5800000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9620517936285105
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9757787397919786
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -8.307405277930998e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.318925062559794e-13
# D_store[count] = D = -0.56
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9580596603856761
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9730466919963264
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -3.4044760747352364e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.941124839956357e-14
# D_store[count] = D = -0.54
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9536288216854157
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9699838530482097
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.9848696093894377e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 8.229592830689657e-17
# D_store[count] = D = -0.52
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9487080114200387
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9665463997059517
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.474715037956251e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.653889763942179e-14
# D_store[count] = D = -0.5
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9432394374426707
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9626840370813039
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.876520452421931e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.6706129673383492e-14
# D_store[count] = D = -0.48
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9371578725682537
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9583389425492674
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.1784073976995845e-9
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.513524309482097e-9
# D_store[count] = D = -0.45999999999999996
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9303895851615799
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9534444906233338
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 7.937424205803422e-11
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 6.684953613945305e-14
# D_store[count] = D = -0.43999999999999995
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9228510770913267
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9479237297923383
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -3.841478010487049e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.982398476962245e-13
# D_store[count] = D = -0.42
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9144475896143281
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9416875729267606
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.7244599302311016e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -6.718542281069611e-14
# D_store[count] = D = -0.39999999999999997
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.9050714037299965
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9346325373308605
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.204177697626035e-11
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.5181829349663194e-9
# D_store[count] = D = -0.37999999999999995
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8945997481759719
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9266381611728521
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.448929276676438e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.6732410647251026e-9
# D_store[count] = D = -0.35999999999999993
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8828923146213477
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9175636837893494
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 8.715039829007068e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.493887787666049e-13
# D_store[count] = D = -0.3399999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8697882852586307
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.9072440530956023
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.764799781779782e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 9.928192659258294e-14
# D_store[count] = D = -0.3199999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8551026384539753
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.8954849121973417
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.9244392367235864e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.307410616655829e-13
# D_store[count] = D = -0.30000000000000004
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8386216917380949
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.8820563816316266
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -4.295101424401473e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.1401522099535738e-13
# D_store[count] = D = -0.28
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.8200973155051168
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.8666850311080674
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -6.003489066409128e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.570301212698363e-15
# D_store[count] = D = -0.26
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.7992397447450879
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.849043613651312
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -1.0092436220610571e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 1.765280804467037e-14
# D_store[count] = D = -0.24
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.7757079656020642
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.8287375050838682
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -2.226730097926435e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 5.4575773368884464e-14
# D_store[count] = D = -0.21999999999999997
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.7490969599642154
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.8052865241347511
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 5.383773235304999e-16
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 3.408338890489573e-14
# D_store[count] = D = -0.19999999999999996
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.7189199125238402
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.7780997632748208
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -2.085930719890683e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 4.604145903965749e-10
# D_store[count] = D = -0.1800000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.6845826459170692
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.7464397740107402
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.630236432523731e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -2.64865851980989e-14
# D_store[count] = D = -0.1600000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.6453449821549366
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.7093692593045333
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -2.845223890040293e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 2.776061604690979e-14
# D_store[count] = D = -0.14000000000000007
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.6002593056989037
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.6656676470387826
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -3.0629263575910433e-15
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -4.1993801311740484e-14
# D_store[count] = D = -0.12000000000000005
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.5480653904782381
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.6136914297546523
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 6.696519380101268e-9
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.6027512741741392e-9
# D_store[count] = D = -0.10000000000000003
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.48699408287689705
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.5511181193929877
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -3.812385396267336e-10
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -7.761456284895417e-11
# D_store[count] = D = -0.08000000000000002
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.4143516791817631
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.47441469099548417
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = -9.200508755392518e-14
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.3437867550662414e-13
# D_store[count] = D = -0.06000000000000005
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.3254614894897624
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.3775027445720452
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 3.1063036703611403e-12
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = -1.2106166950525863e-13
# D_store[count] = D = -0.040000000000000036
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.20988842368287125
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.2470691620656587
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 1.7629708501343876e-11
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 4.578242976779322e-11
# D_store[count] = D = -0.020000000000000018
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 0.003822642024179785
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 0.004585240739552767
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.5250736165369161
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.5051693944903838
# D_store[count] = D = 0.0
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 3.6696650300940605e-13
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 4.434188061053296e-13
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.8191781364796544
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.7942990946915196
# D_store[count] = D = 0.020000000000000018
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.4417139451004132e-20
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 2.1480149038587065e-20
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.8671921140820779
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.8445351252472716
# D_store[count] = D = 0.040000000000000036
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.5381015699189417e-22
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.7661382148061252e-22
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.8946101042209278
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.874132093432208
# D_store[count] = D = 0.06000000000000005
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.7330054916769849e-18
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.5726574981324054e-21
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9133084155207135
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.8948069448438336
# D_store[count] = D = 0.08000000000000007
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 5.894517932437362e-18
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.3273446034967609e-18
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9271511818590917
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9104197275702443
# D_store[count] = D = 0.10000000000000009
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.5526010566871516e-23
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -5.551806949903234e-23
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9379012452979542
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9227525547062668
# D_store[count] = D = 0.1200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 3.828663101269023e-23
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.2266899754479256e-23
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9465154121451934
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.932784047089073
# D_store[count] = D = 0.1399999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 3.0859203619884995e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.6191604751795667e-22
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9535724583536609
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9411129948092457
# D_store[count] = D = 0.15999999999999992
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.4688921296814944e-19
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.7073628571719223e-19
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9594495781931442
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9481340243607058
# D_store[count] = D = 0.17999999999999994
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 3.426795505186029e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 3.2443573843851893e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9644063453099608
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9541216906653402
# D_store[count] = D = 0.19999999999999996
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -2.424701542265901e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.7329985751649922e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9686289871953715
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9592750786540737
# D_store[count] = D = 0.21999999999999997
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 5.778734041630757e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 4.09224106222536e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9722555641452867
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9637433201595779
# D_store[count] = D = 0.24
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.323481021061428e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.1914750158671282e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9753911309510026
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9676410508855727
# D_store[count] = D = 0.26
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -6.1983777873940905e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -4.274080235163067e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.978117424816296
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9710583438540171
# D_store[count] = D = 0.28
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.1339355874034388e-26
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -8.058164678967332e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9804991646461002
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9740672081680625
# D_store[count] = D = 0.30000000000000004
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 6.374143106049787e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.1452983921778239e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9825884020025756
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9767261051058919
# D_store[count] = D = 0.32000000000000006
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -2.7819964569358744e-22
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 5.360773620474443e-22
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9844275303383462
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9790830882702626
# D_store[count] = D = 0.3400000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.1603639159766035e-17
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -7.034233914563267e-18
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9860514845472081
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9811781103347823
# D_store[count] = D = 0.3600000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -2.585620101714535e-18
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 9.745244839643499e-19
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9874893241104923
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9830446966797342
# D_store[count] = D = 0.3799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -2.712166488806242e-23
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -2.2310827244945208e-21
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9887654277205278
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9847112143022653
# D_store[count] = D = 0.3999999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -6.498856201367266e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -7.105509394511053e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9899003912165062
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9862018348496085
# D_store[count] = D = 0.41999999999999993
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 9.373480224030559e-24
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 2.2099819346835927e-20
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9909117499717953
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9875372987853485
# D_store[count] = D = 0.43999999999999995
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -5.4604941994398135e-18
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -5.472200376053968e-17
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9918145025911089
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9887354923584033
# D_store[count] = D = 0.45999999999999996
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.6652190246916938e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -2.0096372052059693e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9926215584476499
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9898119261614654
# D_store[count] = D = 0.48
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.892954655050728e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -2.398270851337749e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9933440620571091
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9907800975824398
# D_store[count] = D = 0.5
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 9.954147196162988e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.5874062600511286e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9939916909022938
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9916518102755087
# D_store[count] = D = 0.52
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 4.059293896443094e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -5.516736522207969e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9945728787083665
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9924374256933077
# D_store[count] = D = 0.54
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -6.5264591018574845e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 4.830727788915218e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9950949854739003
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9931460500737308
# D_store[count] = D = 0.56
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.5883360907258425e-27
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 5.2900656333139015e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9955644737301969
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9937857332328027
# D_store[count] = D = 0.5800000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -9.330065211541985e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.203099044191907e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9959870211492501
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9943635943482335
# D_store[count] = D = 0.6000000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.7313489836120389e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.6928222577455728e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.996367631891198
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.994885948364188
# D_store[count] = D = 0.6200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -3.4964467956139747e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -6.159067162619227e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9967107267160055
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9953584087317571
# D_store[count] = D = 0.6399999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -7.132230545893377e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.0076273282263753e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.997020219275741
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9957859749485352
# D_store[count] = D = 0.6599999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -2.7767209891356177e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.300172421597877e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9972995810200733
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9961731075117568
# D_store[count] = D = 0.6799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -6.763038000469406e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.8857400932535875e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9975518966601514
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.996523792383289
# D_store[count] = D = 0.7
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 6.438349556096784e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 7.857102397381018e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9977799117607468
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9968415966652937
# D_store[count] = D = 0.72
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -9.013314926602223e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 3.2746225701488206e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9979860751409867
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9971297184548781
# D_store[count] = D = 0.74
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 5.4883997536294235e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -3.442014165567444e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9981725683079188
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9973910220796257
# D_store[count] = D = 0.76
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 4.436371174379294e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.4473171871825169e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9983413458428819
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9976280856305879
# D_store[count] = D = 0.78
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.0845459175858506e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.5971721541256547e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9984941551673074
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9978432252135438
# D_store[count] = D = 0.8
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 9.259219973765377e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -9.589532603849222e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9986325617730504
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9980385252778768
# D_store[count] = D = 0.8200000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 6.703267668527845e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -1.4656086237180244e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9987579696173067
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9982158634184781
# D_store[count] = D = 0.8400000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 4.217630427087231e-19
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -2.3337365004466037e-20
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9988716334449418
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9983769268825595
# D_store[count] = D = 0.8600000000000001
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 2.1022109953165093e-20
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.1842652920450939e-20
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.998974698098732
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9985232547920287
# D_store[count] = D = 0.8799999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -4.0239868447448923e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 2.0807918300733442e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9990681790663736
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.998656222982005
# D_store[count] = D = 0.8999999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -6.518822919001055e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = -3.597870676046108e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9991529827984694
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9987770669547298
# D_store[count] = D = 0.9199999999999999
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.3845746831879393e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 2.8408902687740384e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9992299404917593
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9988869181334575
# D_store[count] = D = 0.94
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = 1.4816487626357515e-28
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 3.8651782507349264e-27
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.999299795910107
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.998986794435666
# D_store[count] = D = 0.96
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.4504576889443043e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 1.0129476966911926e-26
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9993632197852313
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9990776169004496
# D_store[count] = D = 0.98
# SOPX_odd_end[count] = real(KitaevSymmetryX(Kita, round_even(N / 2), N - 1)) = -1.1724072730412694e-29
# SOPZ_odd_end[count] = real(KitaevSymmetryZ(Kita, round_even(N / 2), N - 1)) = 3.9484408088535543e-28
# SOPX_even_end[count] = real(KitaevSymmetryX(Kita, round_odd(N / 2), N)) = 0.9994208173522101
# SOPZ_even_end[count] = real(KitaevSymmetryZ(Kita, round_odd(N / 2), N)) = 0.9991602193002939
# D_store[count] = D = 1.0

# %%
N=600
sweep=0.15
D_length=101
acc=1E-10
using DelimitedFiles
SOPX_odd_end=readdlm("y_end_SOPX_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_odd_end=readdlm("y_end_SOPZ_end_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPX_even_end=readdlm("y_end_SOPX_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_even_end=readdlm("y_end_SOPZ_end_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
D_store=LinRange(-1,1,D_length)
SOPX_odd_bulk=readdlm("y_end_SOPX_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_odd_bulk=readdlm("y_end_SOPZ_bulk_odd_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPX_even_bulk=readdlm("y_end_SOPX_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',')
SOPZ_even_bulk=readdlm("y_end_SOPZ_bulk_even_DimerisedKG_phi=$sweep points=$D_length N=$N accuracy= $acc.csv",',');
# Out:
# 101×1 Matrix{Float64}:
#  -1.037440035557759e-26
#  -9.433225358296323e-27
#   2.0383447892363687e-27
#  -7.036594413851243e-27
#  -6.270753517075535e-27
#   3.8015929327416284e-28
#   4.281997700361114e-21
#  -7.924871496043344e-21
#  -2.489797766892023e-27
#  -3.170024797606011e-27
#  -8.113413361571433e-27
#  -2.3787876103703408e-27
#  -4.510834631463021e-28
#   ⋮
#   0.9952617972389609
#   0.9956911021045455
#   0.9960808979388365
#   0.9964349099802672
#   0.9967564948051312
#   0.9970486952746491
#   0.9973142517006707
#   0.9975556294746756
#   0.9977750752181367
#   0.9979746154568133
#   0.9981560845914482
#   0.998321143832193

# %%
using Plots
using LaTeXStrings
pyplot()
    p1= plot(D_store,SOPX_even_end,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPX_even_end,label=L"O_{e}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:red)
    plot!(D_store,SOPX_odd_end,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPX_odd_end,label=L"O_{o}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:green)
    plot!(D_store,SOPZ_even_end,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPZ_even_end,label=L"O_{e}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:red)
    plot!(D_store,SOPZ_odd_end,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPZ_odd_end,label=L"O_{o}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:green)
    xlabel!(L"\log_{10}(g)")
    ylabel!(L"O_{e/o}^{x/z}")
    #png("y_end_SOPX_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
png("y_end_SOP_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
using Plots
using LaTeXStrings
pyplot()
    p1= plot(D_store,SOPX_even_bulk,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPX_even_bulk,label=L"O_{e}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:red)
    plot!(D_store,SOPX_odd_bulk,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,SOPX_odd_bulk,label=L"O_{o}^{x}",legend=:right,dpi=300,markersize=4,reuse=false,markercolor=:green)
    plot!(D_store,SOPZ_even_bulk,title ="ϕ=-0.15π ; N=$N",label=false,legend=:top,fmt = :png,linestyle=:dash,dpi=300,reuse=false,linecolor=:red,xguidefontsize=10,yguidefontsize=10,legendfontsize=10,xtickfontsize=10,ytickfontsize=10,titlefontsize=12) 
    scatter!(D_store,SOPZ_even_bulk,label=L"O_{e}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:red)
    plot!(D_store,abs.SOPZ_odd_bulk,label=false,legend=:top,fmt=:png,linestyle=:solid,dpi=300,reuse=false,linecolor=:green)
    scatter!(D_store,abs.(SOPZ_odd_bulk),label=L"O_{o}^{z}",legend=:right,dpi=300,markersize=4,markershape=:xcross,reuse=false,markercolor=:green)
    xlabel!(L"\log_{10}(g)")
    ylabel!(L"O_{e/o}^{x/z}")
    #png("y_end_SOPX_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")

# %%
png("y_end_SOPX_bulk_DimerisedKG_phi=-$sweep π points=$D_length N=$N accuracy= $acc")
